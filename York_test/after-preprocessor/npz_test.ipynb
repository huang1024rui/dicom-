# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

path1 = "C:/Users/HQR/Python_npz/1.npz"
data1 = np.load(path1)
data1.files
# Out:
# ['vol', 'seg']

# %%
img_data1 = data1['vol']
seg_data1 = data1['seg']
# show the details
img_data1.shape
# Out:
# (2, 200, 200, 16)

# %%
seg_data1.shape
# Out:
# (2, 200, 200, 16)

# %%
plt.imshow(img_data1[1,:,:,1])

# %%
plt.imshow(seg_data1[1,:,:,1])
